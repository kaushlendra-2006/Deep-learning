# %%
import sqlite3
import numpy as np

# %%
conn=sqlite3.connect('vector-db.db')

cursor=conn.cursor()

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS vectors (id INTEGER PRIMARY KEY, vector BLOB)")

# %%
vec1=np.array([1.2,3.4,2.1,0.8])
vec2=np.array([2.7,1.5,3.9,2.3])

# %%
vec1.tobytes()
# Out:
# b'333333\xf3?333333\x0b@\xcd\xcc\xcc\xcc\xcc\xcc\x00@\x9a\x99\x99\x99\x99\x99\xe9?'

# %%
cursor.execute("INSERT INTO vectors (vector) VALUES (?)", (vec1.tobytes(),))

# %%
cursor.execute("INSERT INTO vectors (vector) VALUES (?)",
# Out:
#   File "/tmp/ipykernel_4857/3571003059.py", line 1
#     cursor.execute("INSERT INTO vectors (vector) VALUES (?)",
#                                                               ^
# SyntaxError: incomplete input
